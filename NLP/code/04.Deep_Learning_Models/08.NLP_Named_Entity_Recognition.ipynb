# %%
import pickle

# %%
# !wget -nc https://lazyprogrammer.me/course_files/nlp/ner_train.pkl
# !wget -nc https://lazyprogrammer.me/course_files/nlp/ner_test.pkl
# Out:
# --2025-10-09 20:13:29--  https://lazyprogrammer.me/course_files/nlp/ner_train.pkl
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4757208 (4.5M) [application/octet-stream]
# Saving to: ‘ner_train.pkl’
#
# ner_train.pkl       100%[===================>]   4.54M  16.3MB/s    in 0.3s
#
# 2025-10-09 20:13:30 (16.3 MB/s) - ‘ner_train.pkl’ saved [4757208/4757208]
#
# --2025-10-09 20:13:30--  https://lazyprogrammer.me/course_files/nlp/ner_test.pkl
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1201978 (1.1M) [application/octet-stream]
# Saving to: ‘ner_test.pkl’
#
# ner_test.pkl        100%[===================>]   1.15M  --.-KB/s    in 0.03s
#
# 2025-10-09 20:13:30 (37.1 MB/s) - ‘ner_test.pkl’ saved [1201978/1201978]

# %% [markdown]
# grab the whole code from NLP_Parts_of_Speech_Tagging script and test it again.
