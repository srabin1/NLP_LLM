# %%
# Slower but always guaranteed to work
# !wget -nc https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz

# You are better off just downloading this from the source
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?usp=sharing
# https://code.google.com/archive/p/word2vec/
# Out:
# --2025-09-25 14:04:12--  https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721807.ca.archive.org/0/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz [following]
# --2025-09-25 14:04:12--  https://dn721807.ca.archive.org/0/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving dn721807.ca.archive.org (dn721807.ca.archive.org)... 204.62.247.89
# Connecting to dn721807.ca.archive.org (dn721807.ca.archive.org)|204.62.247.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/octet-stream]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  38.0MB/s    in 40s
#
# 2025-09-25 14:04:53 (38.9 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
import gdown

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)

# %%
from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
def find_analogies(w1, w2, w3):
  # w1 - w2 = ? - w3
  # e.g. king - man = ? - woman
  #      ? = +king +woman -man
  r = word_vectors.most_similar(positive=[w1, w3], negative=[w2])
  print("%s - %s = %s - %s" % (w1, w2, r[0][0], w3))

# %%
find_analogies('king', 'man', 'woman')
# Out:
# king - man = queen - woman

# %%
find_analogies('france', 'paris', 'london')
# Out:
# france - paris = england - london

# %%
find_analogies('france', 'paris', 'rome')
# Out:
# france - paris = italy - rome

# %%
find_analogies('paris', 'france', 'italy')
# it gives the poor result here
# Out:
# paris - france = lohan - italy

# %%
find_analogies('france', 'french', 'english')
# Out:
# france - french = england - english

# %%
find_analogies('japan', 'japanese', 'chinese')
# poor result
# Out:
# japan - japanese = tibet - chinese

# %%
find_analogies('japan', 'japanese', 'italian')
# Out:
# japan - japanese = italy - italian

# %%
find_analogies('december', 'november', 'june')
# Out:
# december - november = september - june

# %%
find_analogies('miami', 'florida', 'texas')
# Out:
# miami - florida = dallas - texas

# %%
find_analogies('einstein', 'scientist', 'painter')
# Out:
# einstein - scientist = jude - painter

# %%
find_analogies('man', 'woman', 'she')
# Out:
# man - woman = he - she

# %%
find_analogies('man', 'woman', 'aunt')
# Out:
# man - woman = uncle - aunt

# %%
find_analogies('man', 'woman', 'sister')
# Out:
# man - woman = brother - sister

# %%
find_analogies('man', 'woman', 'wife')
# poor analogy
# Out:
# man - woman = son - wife

# %%
find_analogies('man', 'woman', 'actress')
# Out:
# man - woman = actor - actress

# %%
find_analogies('man', 'woman', 'mother')
# Out:
# man - woman = father - mother

# %%
find_analogies('nephew', 'niece', 'aunt')
# Out:
# nephew - niece = uncle - aunt

# %%
def nearest_neighbors(w):
  r = word_vectors.most_similar(positive=[w])
  print("neighbors of: %s" % w)
  for word, score in r:
    print("\t%s" % word)

# %%
nearest_neighbors('king')
# Out:
# neighbors of: king
# 	kings
# 	queen
# 	monarch
# 	crown_prince
# 	prince
# 	sultan
# 	ruler
# 	princes
# 	Prince_Paras
# 	throne

# %%
nearest_neighbors('france')
# Out:
# neighbors of: france
# 	spain
# 	french
# 	germany
# 	europe
# 	italy
# 	england
# 	european
# 	belgium
# 	usa
# 	serbia

# %%
nearest_neighbors('japan')
# Out:
# neighbors of: japan
# 	japanese
# 	tokyo
# 	america
# 	europe
# 	germany
# 	chinese
# 	india
# 	hawaii
# 	usa
# 	korea

# %%
nearest_neighbors('einstein')
# poor results
# Out:
# neighbors of: einstein
# 	nikki
# 	lmfao
# 	albert
# 	armstrong
# 	joan
# 	becky
# 	mcmahon
# 	conrad
# 	lori
# 	haley

# %%
nearest_neighbors('woman')
# Out:
# neighbors of: woman
# 	man
# 	girl
# 	teenage_girl
# 	teenager
# 	lady
# 	teenaged_girl
# 	mother
# 	policewoman
# 	boy
# 	Woman

# %%
nearest_neighbors('nephew')
# Out:
# neighbors of: nephew
# 	son
# 	uncle
# 	brother
# 	grandson
# 	cousin
# 	father
# 	niece
# 	younger_brother
# 	nephews
# 	stepson

# %%
nearest_neighbors('february')
# Out:
# neighbors of: february
# 	january
# 	april
# 	september
# 	december
# 	july
# 	october
# 	november
# 	june
# 	feb
# 	norway

# %%
# Exercise: download pretrained GloVe vectors from
# https://nlp.stanford.edu/projects/glove/
#
# Implement your own find_analogies() and nearest_neighbors()
#
# Hint: you do NOT have to go hunting around on Stackoverflow
#       you do NOT have to copy and paste code from anywhere
#       look at the file you downloaded
